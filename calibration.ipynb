# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#time scale is at 30 seconds, threshold at 30mv
voltages = [500,1000,1200,1400,1600,1800,2000,2100]
counts = [0,0,1,75,847,1978,2520,3290]

# %%
plt.figure()
plt.plot(voltages,counts,marker='.',linestyle="")
plt.show()

# %%
#time scale is at 30 seconds, threshold at 80mv
voltages = [500,1000,1200,1400,1600,1800,2000,2100]
counts = [0,0,1,75,847,725,2112,2397]
plt.figure()
plt.plot(voltages,counts,marker='.',linestyle="")
plt.show()

# %%
#time scale is at 30 seconds, threshold at 80mv
voltages = [1600,1800,1900,2000,2100]
counts = [83,601,1486,1925,2305]
plt.figure()
plt.plot(voltages,counts,marker='.',linestyle="")
plt.show()
